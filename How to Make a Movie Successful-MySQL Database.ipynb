# %% [markdown]
# ![image.png](attachment:image.png)
#
# # How to Make a Movie Successful
#
# - Kevin Barnett
# > Data Dictionary: https://www.imdb.com/interfaces/

# %% [markdown]
# ## Import Libraries and Data

# %%
import numpy as np
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy.types import Integer, Float, String, Text

# %%
# Show all columns
pd.set_option('display.max_columns', None)

# tmdb combined data
df_tmdb = pd.read_csv("C:\\Data\\tmdb_results_combined.csv.gz")
df_tmdb
# Out:
#       Unnamed: 0    imdb_id  adult                     backdrop_path  \
# 0              0          0    NaN                               NaN
# 1              1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2              2  tt0113092    0.0                               NaN
# 3              3  tt0116391    0.0                               NaN
# 4              4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...          ...        ...    ...                               ...
# 2467        2467  tt6174238    0.0                               NaN
# 2468        2468  tt7029820    0.0                               NaN
# 2469        2469  tt7197642    0.0                               NaN
# 2470        2470  tt7631368    0.0  /sF0gUHE0YzZNXYugTB2LFxJIppf.jpg
# 2471        2471  tt7802790    0.0  /etxml2M8GQzb31jcH0cdA489WCX.jpg
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...                    ...         ...
# 2467                   NaN         0.0
# 2468                   NaN      7000.0
# 2469                   NaN         0.0
# 2470                   NaN  10000000.0
# 2471                   NaN         0.0
#
#                                                  genres homepage        id  \
# 0                                                   NaN      NaN       NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 2              [{'id': 878, 'name': 'Science Fiction'}]      NaN  110977.0
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN  442869.0
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN     843.0
# ...                                                 ...      ...       ...
# 2467                      [{'id': 80, 'name': 'Crime'}]      NaN  223878.0
# 2468                                                 []      NaN  604889.0
# 2469                     [{'id': 35, 'name': 'Comedy'}]      NaN  872676.0
# 2470                     [{'id': 27, 'name': 'Horror'}]      NaN   97186.0
# 2471  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      NaN  610992.0
#
#      original_language           original_title  \
# 0                  NaN                      NaN
# 1                   en          The Fantasticks
# 2                   en            For the Cause
# 3                   hi                     Gang
# 4                   cn                     花樣年華
# ...                ...                      ...
# 2467                cn                       冷战
# 2468                en     Scream For Christmas
# 2469                en  Goodbye, Merry-Go-Round
# 2470                fr               I, Vampire
# 2471                fa                مومیایی ۳
#
#                                                overview  popularity  \
# 0                                                   NaN         NaN
# 1     Two rural teens sing and dance their way throu...       2.472
# 2     Earth is in a state of constant war and two co...       1.819
# 3     After falling prey to underworld, four friends...       0.915
# 4     Two neighbors become intimate after discoverin...      27.592
# ...                                                 ...         ...
# 2467  Since the death of his wife three years ago, K...       1.248
# 2468  A Christmas party is interrupted by a violent ...       0.600
# 2469                                   Maryland  comedy       0.600
# 2470  A sensual trilogy of vampire stories from Wiza...       0.600
# 2471  Officer Ghorbani is a good and on time police ...       0.621
#
#                            poster_path  \
# 0                                  NaN
# 1     /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 2     /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 3     /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 4     /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# ...                                ...
# 2467  /4p58ILmqsfPGS9iRCX3riekJt8e.jpg
# 2468  /aamgNb0C0cuU7NKT03eUeJL92bH.jpg
# 2469                               NaN
# 2470  /cl47LE7zYELjTzH7gfyvzBrCG5W.jpg
# 2471  /3GLAvhgHNpJzB1FgD1qh00qDxPG.jpg
#
#                                    production_companies  \
# 0                                                   NaN
# 1     [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 2     [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 3                                                    []
# 4     [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# ...                                                 ...
# 2467                                                 []
# 2468  [{'id': 185524, 'logo_path': None, 'name': 'Wo...
# 2469                                                 []
# 2470                                                 []
# 2471  [{'id': 119987, 'logo_path': None, 'name': 'Ha...
#
#                                    production_countries release_date  \
# 0                                                   NaN          NaN
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15
# 3               [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14
# 4     [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2000-09-29
# ...                                                 ...          ...
# 2467        [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-06-17
# 2468                                                 []   2000-01-01
# 2469  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-12-12
# 2470                                                 []   2000-10-17
# 2471             [{'iso_3166_1': 'IR', 'name': 'Iran'}]   2000-02-01
#
#          revenue  runtime                                   spoken_languages  \
# 0            NaN      NaN                                                NaN
# 1            0.0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3            0.0    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 4     12854953.0     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# ...          ...      ...                                                ...
# 2467         0.0      0.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 2468         0.0     80.0                                                 []
# 2469         0.0     90.0                                                 []
# 2470         0.0     85.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2471         0.0     98.0  [{'english_name': 'Persian', 'iso_639_1': 'fa'...
#
#         status                                            tagline  \
# 0          NaN                                                NaN
# 1     Released      Try to remember the first time magic happened
# 2     Released       The ultimate showdown on a forbidden planet.
# 3     Released                                                NaN
# 4     Released  Feel the heat, keep the feeling burning, let t...
# ...        ...                                                ...
# 2467  Released                                                NaN
# 2468  Released                                                NaN
# 2469  Released                                                NaN
# 2470  Released                                                NaN
# 2471  Released                                                NaN
#
#                         title  video  vote_average  vote_count certification
# 0                         NaN    NaN           NaN         NaN           NaN
# 1             The Fantasticks    0.0         5.500        22.0           NaN
# 2               For the Cause    0.0         5.100         8.0           NaN
# 3                        Gang    0.0         4.000         1.0           NaN
# 4        In the Mood for Love    0.0         8.114      2188.0            PG
# ...                       ...    ...           ...         ...           ...
# 2467                 Cold War    0.0         2.000         2.0           NaN
# 2468     Scream For Christmas    0.0         0.000         0.0           NaN
# 2469  Goodbye, Merry-Go-Round    0.0         0.000         0.0           NaN
# 2470               I, Vampire    0.0         6.400         4.0            NR
# 2471              The Mummy 3    0.0         7.000         1.0           NaN
#
# [2472 rows x 27 columns]

# %%
# Check column names for extra spaces
list(df_tmdb.columns)
# Out:
# ['Unnamed: 0',
#  'imdb_id',
#  'adult',
#  'backdrop_path',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count',
#  'certification']

# %%
# Title basics
title_basics = pd.read_csv("C:\\Data\\title_basics.csv.gz")
title_basics.head()
# Out:
#       tconst titletype                                       primarytitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originaltitle  isadult  startyear endyear  \
# 0                             Kate & Leopold        0     2001.0  np.nan
# 1  El tango del viudo y su espejo deformante        0     2020.0  np.nan
# 2                 The Other Side of the Wind        0     2018.0  np.nan
# 3                          The Naked Monster        0     2005.0  np.nan
# 4                       Crime and Punishment        0     2002.0  np.nan
#
#    runtimeminutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
# Title rating
title_rating = pd.read_csv("C:\\Data\\title_rating.csv.gz")
title_rating.head()
# Out:
#       tconst  averagerating  numvotes
# 0  tt0000001            5.7      1967
# 1  tt0000002            5.8       264
# 2  tt0000005            6.2      2610
# 3  tt0000006            5.2       181
# 4  tt0000007            5.4       816

# %%
# Remove unnecessary columns/rows
# Remove 'Unamed:0' column from df_tmdb
df_tmdb = df_tmdb.drop(columns='Unnamed: 0')
df_tmdb = df_tmdb.drop([0], axis=0)
df_tmdb.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 5  tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg                   NaN
#
#        budget                                             genres homepage  \
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
# 5         0.0                      [{'id': 18, 'name': 'Drama'}]      NaN
#
#          id original_language   original_title  \
# 1   62127.0                en  The Fantasticks
# 2  110977.0                en    For the Cause
# 3  442869.0                hi             Gang
# 4     843.0                cn             花樣年華
# 5   49511.0                en   Chinese Coffee
#
#                                             overview  popularity  \
# 1  Two rural teens sing and dance their way throu...       2.472
# 2  Earth is in a state of constant war and two co...       1.819
# 3  After falling prey to underworld, four friends...       0.915
# 4  Two neighbors become intimate after discoverin...      27.592
# 5  When Harry Levine, an aging, unsuccessful Gree...       4.290
#
#                         poster_path  \
# 1  /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 2  /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 3  /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 4  /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 5  /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
#
#                                 production_companies  \
# 1  [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 2  [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 3                                                 []
# 4  [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# 5  [{'id': 67930, 'logo_path': None, 'name': 'Cha...
#
#                                 production_countries release_date     revenue  \
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22         0.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15         0.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14         0.0
# 4  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2000-09-29  12854953.0
# 5  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02         0.0
#
#    runtime                                   spoken_languages    status  \
# 1     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 5     99.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 5  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average  vote_count certification
# 1    0.0         5.500        22.0           NaN
# 2    0.0         5.100         8.0           NaN
# 3    0.0         4.000         1.0           NaN
# 4    0.0         8.114      2188.0            PG
# 5    0.0         6.800        49.0             R

# %%
# Reset index
df_tmdb = df_tmdb.reset_index(drop=True)
df_tmdb.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1  tt0113092    0.0                               NaN                   NaN
# 2  tt0116391    0.0                               NaN                   NaN
# 3  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4  tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 1         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 2         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 3    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
# 4         0.0                      [{'id': 18, 'name': 'Drama'}]      NaN
#
#          id original_language   original_title  \
# 0   62127.0                en  The Fantasticks
# 1  110977.0                en    For the Cause
# 2  442869.0                hi             Gang
# 3     843.0                cn             花樣年華
# 4   49511.0                en   Chinese Coffee
#
#                                             overview  popularity  \
# 0  Two rural teens sing and dance their way throu...       2.472
# 1  Earth is in a state of constant war and two co...       1.819
# 2  After falling prey to underworld, four friends...       0.915
# 3  Two neighbors become intimate after discoverin...      27.592
# 4  When Harry Levine, an aging, unsuccessful Gree...       4.290
#
#                         poster_path  \
# 0  /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1  /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2  /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3  /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4  /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
#
#                                 production_companies  \
# 0  [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 1  [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 2                                                 []
# 3  [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# 4  [{'id': 67930, 'logo_path': None, 'name': 'Cha...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22         0.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15         0.0
# 2            [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14         0.0
# 3  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2000-09-29  12854953.0
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02         0.0
#
#    runtime                                   spoken_languages    status  \
# 0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4     99.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                                NaN                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average  vote_count certification
# 0    0.0         5.500        22.0           NaN
# 1    0.0         5.100         8.0           NaN
# 2    0.0         4.000         1.0           NaN
# 3    0.0         8.114      2188.0            PG
# 4    0.0         6.800        49.0             R

# %% [markdown]
# ## Data Normalization

# %%
# Normalize genres
# Split genres into two tables: 'title_genres' and 'genres'
# Check 'genres' column data type
sample = title_basics.loc[0,'genres']
type(sample)
# Out:
# str

# %%
# Create column with list of genres
title_basics['genres_split'] = title_basics['genres'].str.split(',')
title_basics.head()
# Out:
#       tconst titletype                                       primarytitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originaltitle  isadult  startyear endyear  \
# 0                             Kate & Leopold        0     2001.0  np.nan
# 1  El tango del viudo y su espejo deformante        0     2020.0  np.nan
# 2                 The Other Side of the Wind        0     2018.0  np.nan
# 3                          The Naked Monster        0     2005.0  np.nan
# 4                       Crime and Punishment        0     2002.0  np.nan
#
#    runtimeminutes                  genres                genres_split
# 0             118  Comedy,Fantasy,Romance  [Comedy, Fantasy, Romance]
# 1              70                   Drama                     [Drama]
# 2             122                   Drama                     [Drama]
# 3             100    Comedy,Horror,Sci-Fi    [Comedy, Horror, Sci-Fi]
# 4             126                   Drama                     [Drama]

# %%
# Separate list of genres into new rows
exploded_genres = title_basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titletype                                       primarytitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 81668  tt9916190     movie                                          Safeguard
# 81668  tt9916190     movie                                          Safeguard
# 81668  tt9916190     movie                                          Safeguard
# 81669  tt9916362     movie                                              Coven
# 81669  tt9916362     movie                                              Coven
#
#                                    originaltitle  isadult  startyear endyear  \
# 0                                 Kate & Leopold        0     2001.0  np.nan
# 0                                 Kate & Leopold        0     2001.0  np.nan
# 0                                 Kate & Leopold        0     2001.0  np.nan
# 1      El tango del viudo y su espejo deformante        0     2020.0  np.nan
# 2                     The Other Side of the Wind        0     2018.0  np.nan
# ...                                          ...      ...        ...     ...
# 81668                                  Safeguard        0     2020.0  np.nan
# 81668                                  Safeguard        0     2020.0  np.nan
# 81668                                  Safeguard        0     2020.0  np.nan
# 81669                                   Akelarre        0     2020.0  np.nan
# 81669                                   Akelarre        0     2020.0  np.nan
#
#        runtimeminutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 81668              95  Action,Adventure,Thriller       Action
# 81668              95  Action,Adventure,Thriller    Adventure
# 81668              95  Action,Adventure,Thriller     Thriller
# 81669              92              Drama,History        Drama
# 81669              92              Drama,History      History
#
# [153004 rows x 10 columns]

# %%
# Get unique genres from 'genres_split' column
genres_split = title_basics['genres'].str.split(',')
unique_genres = sorted(genres_split.explode().unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
unique_genres = np.array(unique_genres)
unique_genres
# Out:
# array(['Action', 'Adult', 'Adventure', 'Animation', 'Biography', 'Comedy',
#        'Crime', 'Drama', 'Family', 'Fantasy', 'Game-Show', 'History',
#        'Horror', 'Music', 'Musical', 'Mystery', 'News', 'Reality-TV',
#        'Romance', 'Sci-Fi', 'Short', 'Sport', 'Talk-Show', 'Thriller',
#        'War', 'Western'], dtype='<U10')

# %%
# Create new table 'title_genres'
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
# Make genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_id_map = dict(zip(unique_genres, genre_ints))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
# Make integer id for genres and drop string genres
title_basics['genre_id'] = title_basics['genres_split'].replace(genre_id_map)

# %%
# Drop string genres
title_basics = title_basics.drop(columns='genres_split')
title_basics
# Out:
#           tconst titletype                                       primarytitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 81665  tt9914942     movie                             Life Without Sara Amat
# 81666  tt9915872     movie                               The Last White Witch
# 81667  tt9916170     movie                                      The Rehearsal
# 81668  tt9916190     movie                                          Safeguard
# 81669  tt9916362     movie                                              Coven
#
#                                    originaltitle  isadult  startyear endyear  \
# 0                                 Kate & Leopold        0     2001.0  np.nan
# 1      El tango del viudo y su espejo deformante        0     2020.0  np.nan
# 2                     The Other Side of the Wind        0     2018.0  np.nan
# 3                              The Naked Monster        0     2005.0  np.nan
# 4                           Crime and Punishment        0     2002.0  np.nan
# ...                                          ...      ...        ...     ...
# 81665                 La vida sense la Sara Amat        0     2019.0  np.nan
# 81666                  My Girlfriend is a Wizard        0     2019.0  np.nan
# 81667                                   O Ensaio        0     2019.0  np.nan
# 81668                                  Safeguard        0     2020.0  np.nan
# 81669                                   Akelarre        0     2020.0  np.nan
#
#        runtimeminutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 81665              74                      Drama
# 81666              97       Comedy,Drama,Fantasy
# 81667              51                      Drama
# 81668              95  Action,Adventure,Thriller
# 81669              92              Drama,History
#
#                             genre_id
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                            [Drama]
# ...                              ...
# 81665                        [Drama]
# 81666       [Comedy, Drama, Fantasy]
# 81667                        [Drama]
# 81668  [Action, Adventure, Thriller]
# 81669               [Drama, History]
#
# [81670 rows x 10 columns]

# %%
# Convert genre map dictionary to dataframe
genres = pd.DataFrame({'genre_name': genre_id_map.keys(),
                            'genre_id': genre_id_map.values()})
genres.info()
genres
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   genre_name  26 non-null     object
#  1   genre_id    26 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 544.0+ bytes
#     genre_name  genre_id
# 0       Action         0
# 1        Adult         1
# 2    Adventure         2
# 3    Animation         3
# 4    Biography         4
# 5       Comedy         5
# 6        Crime         6
# 7        Drama         7
# 8       Family         8
# 9      Fantasy         9
# 10   Game-Show        10
# 11     History        11
# 12      Horror        12
# 13       Music        13
# 14     Musical        14
# 15     Mystery        15
# 16        News        16
# 17  Reality-TV        17
# 18     Romance        18
# 19      Sci-Fi        19
# 20       Short        20
# 21       Sport        21
# 22   Talk-Show        22
# 23    Thriller        23
# 24         War        24
# 25     Western        25

# %%
title_basics = title_basics[['tconst','primarytitle','startyear',
                            'runtimeminutes']]
title_basics
# Out:
#           tconst                                       primarytitle  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049                         The Other Side of the Wind
# 3      tt0088751                                  The Naked Monster
# 4      tt0096056                               Crime and Punishment
# ...          ...                                                ...
# 81665  tt9914942                             Life Without Sara Amat
# 81666  tt9915872                               The Last White Witch
# 81667  tt9916170                                      The Rehearsal
# 81668  tt9916190                                          Safeguard
# 81669  tt9916362                                              Coven
#
#        startyear  runtimeminutes
# 0         2001.0             118
# 1         2020.0              70
# 2         2018.0             122
# 3         2005.0             100
# 4         2002.0             126
# ...          ...             ...
# 81665     2019.0              74
# 81666     2019.0              97
# 81667     2019.0              51
# 81668     2020.0              95
# 81669     2020.0              92
#
# [81670 rows x 4 columns]

# %% [markdown]
# ## Saving MySQL Tables

# %%
# Create connection string and engine
username = 'root'
password = 'root'
db_name = 'movies'
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

engine = create_engine(connection)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/movies)

# %%
# Using 'tconst' column as primary key
# Check dataframe dtypes
title_basics.dtypes
# Out:
# tconst             object
# primarytitle       object
# startyear         float64
# runtimeminutes      int64
# dtype: object

# %%
# Create max string lengths for object columns
key_len = title_basics['tconst'].fillna('').map(len).max()
title_len = title_basics['primarytitle'].fillna('').map(len).max()

# Create schema dictionary for title_basics table
basics_schema = {
    'tconst': String(key_len+1),
    'primarytitle': Text(title_len+1),
    'startyear': Float(),
    'endyear': Float(),
    'runtimeminutes': Integer()
}

# %%
# Save title_basics table to SQL
title_basics.to_sql('title_basics',engine,dtype=basics_schema,if_exists='replace',
                   index=False)
# Out:
# 81670

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
# Show first five rows of table
q = '''Select * from title_basics limit 5;'''
pd.read_sql(q, engine)
# Out:
#       tconst                                       primarytitle  startyear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0088751                                  The Naked Monster     2005.0
# 4  tt0096056                               Crime and Punishment     2002.0
#
#    runtimeminutes
# 0             118
# 1              70
# 2             122
# 3             100
# 4             126

# %%
title_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497338 entries, 0 to 497337
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         497338 non-null  object
#  1   averagerating  497338 non-null  float64
#  2   numvotes       497338 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.4+ MB

# %%
# Create schema dictionary for title_rating table
rating_schema = {
    'tconst': String(key_len+1),
    'averagerating': Float(),
    'numvotes': Integer()
}

# %%
# Save title_ratings table to SQL
title_rating.to_sql('title_ratings',engine,dtype=rating_schema,if_exists='replace',
                   index=False)
engine.execute('ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`);')

# %%
# Show first five rows of table
q = '''Select * from title_ratings limit 5;'''
pd.read_sql(q, engine)
# Out:
#       tconst  averagerating  numvotes
# 0  tt0000001            5.7      1967
# 1  tt0000002            5.8       264
# 2  tt0000005            6.2      2610
# 3  tt0000006            5.2       181
# 4  tt0000007            5.4       816

# %%
# Save title_genres table to SQL
title_genres.to_sql('title_genres',engine,if_exists='replace',index=False)
# Out:
# 153004

# %%
# Save genres table to SQL
genres.to_sql('genres',engine,if_exists='replace',index=False)
# Out:
# 26

# %%
# Show first five rows of table
q = '''Select * from genres limit 5;'''
pd.read_sql(q, engine)
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
df_tmdb.info()
df_tmdb.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2471 entries, 0 to 2470
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2471 non-null   object
#  1   adult                  2470 non-null   float64
#  2   backdrop_path          1360 non-null   object
#  3   belongs_to_collection  226 non-null    object
#  4   budget                 2470 non-null   float64
#  5   genres                 2470 non-null   object
#  6   homepage               128 non-null    object
#  7   id                     2470 non-null   float64
#  8   original_language      2470 non-null   object
#  9   original_title         2470 non-null   object
#  10  overview               2426 non-null   object
#  11  popularity             2470 non-null   float64
#  12  poster_path            2226 non-null   object
#  13  production_companies   2470 non-null   object
#  14  production_countries   2470 non-null   object
#  15  release_date           2456 non-null   object
#  16  revenue                2470 non-null   float64
#  17  runtime                2470 non-null   float64
#  18  spoken_languages       2470 non-null   object
#  19  status                 2470 non-null   object
#  20  tagline                1094 non-null   object
#  21  title                  2470 non-null   object
#  22  video                  2470 non-null   float64
#  23  vote_average           2470 non-null   float64
#  24  vote_count             2470 non-null   float64
#  25  certification          782 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 502.0+ KB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1  tt0113092    0.0                               NaN                   NaN
# 2  tt0116391    0.0                               NaN                   NaN
# 3  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4  tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 1         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 2         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 3    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
# 4         0.0                      [{'id': 18, 'name': 'Drama'}]      NaN
#
#          id original_language   original_title  \
# 0   62127.0                en  The Fantasticks
# 1  110977.0                en    For the Cause
# 2  442869.0                hi             Gang
# 3     843.0                cn             花樣年華
# 4   49511.0                en   Chinese Coffee
#
#                                             overview  popularity  \
# 0  Two rural teens sing and dance their way throu...       2.472
# 1  Earth is in a state of constant war and two co...       1.819
# 2  After falling prey to underworld, four friends...       0.915
# 3  Two neighbors become intimate after discoverin...      27.592
# 4  When Harry Levine, an aging, unsuccessful Gree...       4.290
#
#                         poster_path  \
# 0  /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1  /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2  /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3  /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4  /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
#
#                                 production_companies  \
# 0  [{'id': 51207, 'logo_path': None, 'name': 'Sul...
# 1  [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 2                                                 []
# 3  [{'id': 539, 'logo_path': '/iPLtePguIzOPNtAWfT...
# 4  [{'id': 67930, 'logo_path': None, 'name': 'Cha...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22         0.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15         0.0
# 2            [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14         0.0
# 3  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2000-09-29  12854953.0
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02         0.0
#
#    runtime                                   spoken_languages    status  \
# 0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4     99.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                                NaN                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average  vote_count certification
# 0    0.0         5.500        22.0           NaN
# 1    0.0         5.100         8.0           NaN
# 2    0.0         4.000         1.0           NaN
# 3    0.0         8.114      2188.0            PG
# 4    0.0         6.800        49.0             R

# %%
df_tmdb = df_tmdb[['imdb_id','budget','revenue','certification']]
df_tmdb
# Out:
#         imdb_id      budget     revenue certification
# 0     tt0113026  10000000.0         0.0           NaN
# 1     tt0113092         0.0         0.0           NaN
# 2     tt0116391         0.0         0.0           NaN
# 3     tt0118694    150000.0  12854953.0            PG
# 4     tt0118852         0.0         0.0             R
# ...         ...         ...         ...           ...
# 2466  tt6174238         0.0         0.0           NaN
# 2467  tt7029820      7000.0         0.0           NaN
# 2468  tt7197642         0.0         0.0           NaN
# 2469  tt7631368  10000000.0         0.0            NR
# 2470  tt7802790         0.0         0.0           NaN
#
# [2471 rows x 4 columns]

# %%
# Calculate max string lengths for object columns
imdb_len = df_tmdb['imdb_id'].fillna('').map(len).max()
cert_len = df_tmdb['certification'].fillna('').map(len).max()

# %%
# Create schema dictionary for tmdb_data table
tmdb_schema = {
    'imdb_id': String(imdb_len+1),
    'budget': Float(),
    'revenue': Float(),
    'certification': Text(cert_len)
}

# %%
df_tmdb.to_sql('tmdb_data',engine,dtype=tmdb_schema,if_exists='replace',
              index=False)
# engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')
# Out:
# 2471

# %%
# Show first five rows of table
q = '''Select * from tmdb_data limit 5;'''
pd.read_sql(q, engine)
# Out:
#      imdb_id      budget     revenue certification
# 0  tt0113026  10000000.0         0.0          None
# 1  tt0113092         0.0         0.0          None
# 2  tt0116391         0.0         0.0          None
# 3  tt0118694    150000.0  12855000.0            PG
# 4  tt0118852         0.0         0.0             R
