# %% [markdown]
# ![image.png](attachment:image.png)
#
# # How to Make a Movie Successful
#
# - Kevin Barnett
# > Data Dictionary: https://www.imdb.com/interfaces/

# %% [markdown]
# ## Import Libraries and Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy.types import Integer, Float, String, Text
import os, glob
import scipy.stats as stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
def find_outliers(data, verbose=True):
    outliers = np.abs(stats.zscore(data))>3
    
    if verbose:
        print(f"{outliers.sum()} outliers found in {data.name} using Z-Scores.")
    return outliers

# %%
# Test locating csv.gz file and converting to dataframe
dirpath = 'Data/'
test = pd.read_csv(os.path.join(dirpath, 'final_tmdb_data2021.csv.gz'))
test.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0          0    NaN                               NaN
# 1  tt0199602    0.0  /fOnjxCbR3Poar7voHcaQrvYqQMH.jpg
# 2  tt0293429    0.0  /9yBVqNruk6Ykrwc32qrK2TIE5xw.jpg
# 3  tt0499097    0.0  /fPGeS6jgdLovQAKunNHX8l0avCy.jpg
# 4  tt0870154    0.0  /7WJjFviFBffEJvkAms4uWwbcVUk.jpg
#
#                                belongs_to_collection       budget  \
# 0                                                NaN          NaN
# 1                                                NaN          0.0
# 2  {'id': 931431, 'name': 'Mortal Kombat (Reboot)...   20000000.0
# 3                                                NaN          0.0
# 4  {'id': 861429, 'name': 'Jungle Cruise Collecti...  200000000.0
#
#                                               genres  \
# 0                                                NaN
# 1                     [{'id': 35, 'name': 'Comedy'}]
# 2  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                   homepage        id original_language  \
# 0                                      NaN       NaN               NaN
# 1                                      NaN  894346.0                en
# 2        https://www.mortalkombatmovie.net  460465.0                en
# 3     https://www.amazon.com/dp/B08VFD1Y3B  567189.0                en
# 4  https://movies.disney.com/jungle-cruise  451048.0                en
#
#                  original_title  ...      revenue  runtime  \
# 0                           NaN  ...          NaN      NaN
# 1                Holy Hollywood  ...          0.0     82.0
# 2                 Mortal Kombat  ...   84426031.0    110.0
# 3  Tom Clancy's Without Remorse  ...          0.0    109.0
# 4                 Jungle Cruise  ...  220889446.0    127.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1                                                 []  Released
# 2  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                            tagline                         title  video  \
# 0                              NaN                           NaN    NaN
# 1                              NaN                Holy Hollywood    0.0
# 2                   Get over here.                 Mortal Kombat    0.0
# 3  From the author of Rainbow Six.  Tom Clancy's Without Remorse    0.0
# 4                              NaN                 Jungle Cruise    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1         0.000        0.0           NaN
# 2         7.096     5224.0             R
# 3         7.039     2166.0             R
# 4         7.445     4973.0         PG-13
#
# [5 rows x 26 columns]

# %%
path = 'Data/final_tmdb_data*.csv.gz'
chunked_files = sorted(glob.glob(path))
chunked_files
# Out:
# ['Data\\final_tmdb_data2000.csv.gz',
#  'Data\\final_tmdb_data2001.csv.gz',
#  'Data\\final_tmdb_data2002.csv.gz',
#  'Data\\final_tmdb_data2003.csv.gz',
#  'Data\\final_tmdb_data2004.csv.gz',
#  'Data\\final_tmdb_data2005.csv.gz',
#  'Data\\final_tmdb_data2006.csv.gz',
#  'Data\\final_tmdb_data2007.csv.gz',
#  'Data\\final_tmdb_data2008.csv.gz',
#  'Data\\final_tmdb_data2009.csv.gz',
#  'Data\\final_tmdb_data2010.csv.gz',
#  'Data\\final_tmdb_data2011.csv.gz',
#  'Data\\final_tmdb_data2012.csv.gz',
#  'Data\\final_tmdb_data2013.csv.gz',
#  'Data\\final_tmdb_data2014.csv.gz',
#  'Data\\final_tmdb_data2015.csv.gz',
#  'Data\\final_tmdb_data2016.csv.gz',
#  'Data\\final_tmdb_data2017.csv.gz',
#  'Data\\final_tmdb_data2018.csv.gz',
#  'Data\\final_tmdb_data2019.csv.gz',
#  'Data\\final_tmdb_data2020.csv.gz',
#  'Data\\final_tmdb_data2021.csv.gz',
#  'Data\\final_tmdb_data2022.csv.gz']

# %%
tmdb_df = pd.concat([pd.read_csv(file, index_col=0) for file in chunked_files])
tmdb_df.info()
tmdb_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63134 entries, 0 to 0
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  63111 non-null  float64
#  1   backdrop_path          40543 non-null  object
#  2   belongs_to_collection  4212 non-null   object
#  3   budget                 63111 non-null  float64
#  4   genres                 63111 non-null  object
#  5   homepage               15108 non-null  object
#  6   id                     63111 non-null  float64
#  7   original_language      63111 non-null  object
#  8   original_title         63111 non-null  object
#  9   overview               61766 non-null  object
#  10  popularity             63111 non-null  float64
#  11  poster_path            58022 non-null  object
#  12  production_companies   63111 non-null  object
#  13  production_countries   63111 non-null  object
#  14  release_date           61985 non-null  object
#  15  revenue                63111 non-null  float64
#  16  runtime                63111 non-null  float64
#  17  spoken_languages       63111 non-null  object
#  18  status                 63111 non-null  object
#  19  tagline                23988 non-null  object
#  20  title                  63111 non-null  object
#  21  video                  63111 non-null  float64
#  22  vote_average           63111 non-null  float64
#  23  vote_count             63111 non-null  float64
#  24  certification          15204 non-null  object
# dtypes: float64(9), object(16)
# memory usage: 12.5+ MB
#            adult                     backdrop_path belongs_to_collection  \
# imdb_id
# 0            NaN                               NaN                   NaN
# tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# tt0113092    0.0                               NaN                   NaN
# tt0116391    0.0                               NaN                   NaN
# tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#                budget                                             genres  \
# imdb_id
# 0                 NaN                                                NaN
# tt0113026  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# tt0113092         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# tt0116391         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# tt0118694    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#           homepage        id original_language   original_title  \
# imdb_id
# 0              NaN       NaN               NaN              NaN
# tt0113026      NaN   62127.0                en  The Fantasticks
# tt0113092      NaN  110977.0                en    For the Cause
# tt0116391      NaN  442869.0                hi             Gang
# tt0118694      NaN     843.0                cn             花樣年華
#
#                                                     overview  ...     revenue  \
# imdb_id                                                       ...
# 0                                                        NaN  ...         NaN
# tt0113026  Two rural teens sing and dance their way throu...  ...         0.0
# tt0113092  Earth is in a state of constant war and two co...  ...         0.0
# tt0116391  After falling prey to underworld, four friends...  ...         0.0
# tt0118694  Two neighbors become intimate after discoverin...  ...  12854953.0
#
#           runtime                                   spoken_languages  \
# imdb_id
# 0             NaN                                                NaN
# tt0113026    86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# tt0113092   100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# tt0116391   152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# tt0118694    99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
#
#              status                                            tagline  \
# imdb_id
# 0               NaN                                                NaN
# tt0113026  Released      Try to remember the first time magic happened
# tt0113092  Released       The ultimate showdown on a forbidden planet.
# tt0116391  Released                                                NaN
# tt0118694  Released  Feel the heat, keep the feeling burning, let t...
#
#                           title  video vote_average vote_count certification
# imdb_id
# 0                           NaN    NaN          NaN        NaN           NaN
# tt0113026       The Fantasticks    0.0        5.500       22.0           NaN
# tt0113092         For the Cause    0.0        5.100        8.0           NaN
# tt0116391                  Gang    0.0        4.000        1.0           NaN
# tt0118694  In the Mood for Love    0.0        8.119     2204.0            PG
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# Reset index
tmdb_df = tmdb_df.reset_index()
tmdb_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ...     revenue  runtime  \
# 0       NaN               NaN              NaN  ...         NaN      NaN
# 1   62127.0                en  The Fantasticks  ...         0.0     86.0
# 2  110977.0                en    For the Cause  ...         0.0    100.0
# 3  442869.0                hi             Gang  ...         0.0    152.0
# 4     843.0                cn             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         5.500       22.0           NaN
# 2    0.0         5.100        8.0           NaN
# 3    0.0         4.000        1.0           NaN
# 4    0.0         8.119     2204.0            PG
#
# [5 rows x 26 columns]

# %%
# Remove first row that is empty and reset index
tmdb_df = tmdb_df.drop([0], axis=0)
tmdb_df = tmdb_df.reset_index(drop=True)
tmdb_df.info()
tmdb_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63133 entries, 0 to 63132
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                63133 non-null  object
#  1   adult                  63111 non-null  float64
#  2   backdrop_path          40543 non-null  object
#  3   belongs_to_collection  4212 non-null   object
#  4   budget                 63111 non-null  float64
#  5   genres                 63111 non-null  object
#  6   homepage               15108 non-null  object
#  7   id                     63111 non-null  float64
#  8   original_language      63111 non-null  object
#  9   original_title         63111 non-null  object
#  10  overview               61766 non-null  object
#  11  popularity             63111 non-null  float64
#  12  poster_path            58022 non-null  object
#  13  production_companies   63111 non-null  object
#  14  production_countries   63111 non-null  object
#  15  release_date           61985 non-null  object
#  16  revenue                63111 non-null  float64
#  17  runtime                63111 non-null  float64
#  18  spoken_languages       63111 non-null  object
#  19  status                 63111 non-null  object
#  20  tagline                23988 non-null  object
#  21  title                  63111 non-null  object
#  22  video                  63111 non-null  float64
#  23  vote_average           63111 non-null  float64
#  24  vote_count             63111 non-null  float64
#  25  certification          15204 non-null  object
# dtypes: float64(9), object(17)
# memory usage: 12.5+ MB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1  tt0113092    0.0                               NaN                   NaN
# 2  tt0116391    0.0                               NaN                   NaN
# 3  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4  tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 1         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 2         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 3    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
# 4         0.0                      [{'id': 18, 'name': 'Drama'}]      NaN
#
#          id original_language   original_title  ...     revenue  runtime  \
# 0   62127.0                en  The Fantasticks  ...         0.0     86.0
# 1  110977.0                en    For the Cause  ...         0.0    100.0
# 2  442869.0                hi             Gang  ...         0.0    152.0
# 3     843.0                cn             花樣年華  ...  12854953.0     99.0
# 4   49511.0                en   Chinese Coffee  ...         0.0     99.0
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                                NaN                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average vote_count certification
# 0    0.0         5.500       22.0           NaN
# 1    0.0         5.100        8.0           NaN
# 2    0.0         4.000        1.0           NaN
# 3    0.0         8.119     2204.0            PG
# 4    0.0         6.800       49.0             R
#
# [5 rows x 26 columns]

# %%
# Check for extra spaces in column titles
tmdb_df.columns
# Out:
# Index(['imdb_id', 'adult', 'backdrop_path', 'belongs_to_collection', 'budget',
#        'genres', 'homepage', 'id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'certification'],
#       dtype='object')

# %%
# Check for duplicates
tmdb_df.duplicated().sum()
# Out:
# 20

# %%
# Drop duplicates
tmdb_df = tmdb_df.drop_duplicates()
tmdb_df.duplicated().sum()
# Out:
# 0

# %%
# Check for 0 values in 'imdb_id' column
tmdb_df = tmdb_df.loc[tmdb_df['imdb_id']!='0']
tmdb_df
# Out:
#           imdb_id  adult                     backdrop_path  \
# 0       tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1       tt0113092    0.0                               NaN
# 2       tt0116391    0.0                               NaN
# 3       tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 4       tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg
# ...           ...    ...                               ...
# 63128  tt21867430    0.0                               NaN
# 63129  tt22542974    0.0                               NaN
# 63130  tt27056156    0.0                               NaN
# 63131   tt8396416    0.0                               NaN
# 63132           0    NaN                               NaN
#
#       belongs_to_collection      budget  \
# 0                       NaN  10000000.0
# 1                       NaN         0.0
# 2                       NaN         0.0
# 3                       NaN    150000.0
# 4                       NaN         0.0
# ...                     ...         ...
# 63128                   NaN         0.0
# 63129                   NaN         0.0
# 63130                   NaN         0.0
# 63131                   NaN         0.0
# 63132                   NaN         NaN
#
#                                                   genres  \
# 0      [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1               [{'id': 878, 'name': 'Science Fiction'}]
# 2      [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3      [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                          [{'id': 18, 'name': 'Drama'}]
# ...                                                  ...
# 63128                                                 []
# 63129  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 63130                      [{'id': 18, 'name': 'Drama'}]
# 63131                     [{'id': 27, 'name': 'Horror'}]
# 63132                                                NaN
#
#                                   homepage         id original_language  \
# 0                                      NaN    62127.0                en
# 1                                      NaN   110977.0                en
# 2                                      NaN   442869.0                hi
# 3                                      NaN      843.0                cn
# 4                                      NaN    49511.0                en
# ...                                    ...        ...               ...
# 63128                                  NaN  1133367.0                en
# 63129  https://starcitymotionpictures.com/  1138509.0                en
# 63130                                  NaN  1097729.0                en
# 63131                                  NaN  1146433.0                en
# 63132                                  NaN        NaN               NaN
#
#                                 original_title  ...     revenue  runtime  \
# 0                              The Fantasticks  ...         0.0     86.0
# 1                                For the Cause  ...         0.0    100.0
# 2                                         Gang  ...         0.0    152.0
# 3                                         花樣年華  ...  12854953.0     99.0
# 4                               Chinese Coffee  ...         0.0     99.0
# ...                                        ...  ...         ...      ...
# 63128                        Voyage to Procida  ...         0.0      0.0
# 63129  Hell In My Life: The Stacey Staxx Story  ...         0.0    131.0
# 63130        1 Day at a Time in Bessma Alabama  ...         0.0     65.0
# 63131               Human No More: The Feature  ...         0.0    124.0
# 63132                                      NaN  ...         NaN      NaN
#
#                                         spoken_languages    status  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3      [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                  ...       ...
# 63128                                                 []  Released
# 63129  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 63130                                                 []  Released
# 63131  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 63132                                                NaN       NaN
#
#                                                  tagline  \
# 0          Try to remember the first time magic happened
# 1           The ultimate showdown on a forbidden planet.
# 2                                                    NaN
# 3      Feel the heat, keep the feeling burning, let t...
# 4      There's a fine line between friendship and bet...
# ...                                                  ...
# 63128                                                NaN
# 63129                              Based on a true story
# 63130                                                NaN
# 63131                                                NaN
# 63132                                                NaN
#
#                                          title  video  vote_average  \
# 0                              The Fantasticks    0.0         5.500
# 1                                For the Cause    0.0         5.100
# 2                                         Gang    0.0         4.000
# 3                         In the Mood for Love    0.0         8.119
# 4                               Chinese Coffee    0.0         6.800
# ...                                        ...    ...           ...
# 63128                        Voyage to Procida    0.0         0.000
# 63129  Hell In My Life: The Stacey Staxx Story    0.0         0.000
# 63130        1 Day at a Time in Bessma Alabama    0.0         0.000
# 63131               Human No More: The Feature    0.0         0.000
# 63132                                      NaN    NaN           NaN
#
#       vote_count certification
# 0           22.0           NaN
# 1            8.0           NaN
# 2            1.0           NaN
# 3         2204.0            PG
# 4           49.0             R
# ...          ...           ...
# 63128        0.0           NaN
# 63129        0.0           NaN
# 63130        0.0           NaN
# 63131        0.0           NaN
# 63132        NaN           NaN
#
# [63112 rows x 26 columns]

# %%
# Check for missing values in columns of interest
# List of columns
col = tmdb_df[['imdb_id','budget','revenue','certification']]

for i in col.columns:
    missing = col[i].isna().sum()
    

    print(f'There are {missing} missing values in the {i} column')
# Out:
# There are 0 missing values in the imdb_id column
# There are 1 missing values in the budget column
# There are 1 missing values in the revenue column
# There are 47908 missing values in the certification column

# %%
# Check unique values in 'certification' column
tmdb_df['certification'].value_counts(dropna=False)
# Out:
# NaN                                47908
# R                                   6249
# NR                                  3559
# PG-13                               3289
# PG                                  1471
# G                                    455
# NC-17                                171
# Unrated                                5
# UR                                     1
# Not Rated                              1
# ScreamFest Horror Film Festival        1
# PG-13                                  1
# 10                                     1
# Name: certification, dtype: int64

# %%
# fix extra space certs
tmdb_df['certification'] = tmdb_df['certification'].str.strip()

# %%
# Fix values in 'certification' column
cert_replace = {'UR':'NR','Not Rated':'NR','Unrated':'NR',
                'ScreamFest Horror Film Festival':'NR','10':np.nan}
tmdb_df['certification'] = tmdb_df['certification'].replace(cert_replace)
tmdb_df['certification'].value_counts(dropna=False)
# Out:
# NaN      47909
# R         6249
# NR        3567
# PG-13     3290
# PG        1471
# G          455
# NC-17      171
# Name: certification, dtype: int64

# %%
tmdb_df=tmdb_df.dropna(subset='certification')
tmdb_df['certification'].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 tmdb_df=tmdb_df.dropna(subset='certification')
#       2 tmdb_df['certification'].isna().sum()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\frame.py:5950, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    5948 if subset is not None:
#    5949     ax = self._get_axis(agg_axis)
# -> 5950     indices = ax.get_indexer_for(subset)
#    5951     check = indices == -1
#    5952     if check.any():
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:5275, in Index.get_indexer_for(self, target, **kwargs)
#    5263 """
#    5264 Guaranteed return of an indexer even when non-unique.
#    5265
#    (...)
#    5272     List of indices.
#    5273 """
#    5274 if self._index_as_unique:
# -> 5275     return self.get_indexer(target, **kwargs)
#    5276 indexer, _ = self.get_indexer_non_unique(target)
#    5277 return indexer
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3437, in Index.get_indexer(self, target, method, limit, tolerance)
#    3426 @Appender(_index_shared_docs["get_indexer"] % _index_doc_kwargs)
#    3427 @final
#    3428 def get_indexer(
#    (...)
#    3434 ) -> np.ndarray:
#    3435     # returned ndarray is np.intp
#    3436     method = missing.clean_reindex_fill_method(method)
# -> 3437     target = self._maybe_cast_listlike_indexer(target)
#    3439     self._check_indexing_method(method, limit, tolerance)
#    3441     if not self._index_as_unique:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:5708, in Index._maybe_cast_listlike_indexer(self, target)
#    5704 def _maybe_cast_listlike_indexer(self, target) -> Index:
#    5705     """
#    5706     Analogue to maybe_cast_indexer for get_indexer instead of get_loc.
#    5707     """
# -> 5708     return ensure_index(target)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:6336, in ensure_index(index_like, copy)
#    6333         return Index(index_like, copy=copy, tupleize_cols=False)
#    6334 else:
# -> 6336     return Index(index_like, copy=copy)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:474, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     471     return klass._simple_new(arr, name)
#     473 elif is_scalar(data):
# --> 474     raise cls._scalar_data_error(data)
#     475 elif hasattr(data, "__array__"):
#     476     return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, 'certification' was passed

# %%
# Remove rows with revenue AND budget of 0
tmdb_df = tmdb_df.loc[(tmdb_df['budget'] >0 ) & (tmdb_df['revenue']>0)]
tmdb_df.head()

# %%
# Filter out 'imdb_id', 'budget', 'revenue', 'certification' columns
tmdb_df = tmdb_df[['imdb_id','budget','revenue','certification']]
tmdb_df.info()
tmdb_df.head()

# %%
# Calculate max string lengths for object columns
imdb_len = tmdb_df['imdb_id'].fillna('').map(len).max()
cert_len = tmdb_df['certification'].fillna('').map(len).max()

# %%
# Create schema dictionary for tmdb_data table
tmdb_schema = {
    'imdb_id': String(imdb_len+1),
    'budget': Float(),
    'revenue': Float(),
    'certification': Text(cert_len)
}

# %%
# Create connection string and engine
username = 'root'
password = 'root'
db_name = 'movies'
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

engine = create_engine(connection)
engine

# %%
tmdb_df.to_sql('tmdb_data',engine,dtype=tmdb_schema,if_exists='replace',
              index=False)
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %%
# Show first five rows of title_basics table
q = '''Select * from title_basics limit 5;'''
pd.read_sql(q, engine)

# %%
# Show first five rows of title_ratings table
q = '''Select * from title_ratings limit 5;'''
pd.read_sql(q, engine)

# %%
# Show first five rows of genres table
q = '''Select * from genres limit 5;'''
pd.read_sql(q, engine)

# %%
# Show first five rows of title_genres table
q = '''Select * from title_genres limit 5;'''
pd.read_sql(q, engine)

# %%
# Show first five rows of tmdb_data table
q = '''Select * from tmdb_data limit 5;'''
pd.read_sql(q, engine)

# %% [markdown]
# ## Does the MPAA rating of a movie (G/PG/PG-13/R/NC-17) affect how much revenue the movie generates?

# %% [markdown]
# ### Hypotheses and Choosing Test

# %% [markdown]
# **Hypotheses:**
#
#     1. Null Hypothesis: The MPAA rating of a movie does not affect how much revenue a movie generates
#
#     2. Alternative Hypothesis: The MPAA rating of a movie does affect the amount of money a movie generates

# %% [markdown]
# **Choosing the Appropriate Test:**
#
# - The data we are looking for in the groups is numerical (revenue)
# - There are more than two groups (MPAA Rating)
# - ***Test: One Way ANOVA***

# %% [markdown]
# ### One Way Anova Test

# %% [markdown]
# **Test Assumptions:**
#
# - No significant outliers
# - Equal variance
# - Normality

# %%
# Split into MPAA rating groups
g_df = tmdb_df.loc[tmdb_df['certification'] == 'G'].copy()
pg_df = tmdb_df.loc[tmdb_df['certification'] == 'PG'].copy()
pg_13_df = tmdb_df.loc[tmdb_df['certification'] == 'PG-13'].copy()
r_df = tmdb_df.loc[tmdb_df['certification'] == 'R'].copy()
nc_17_df = tmdb_df.loc[tmdb_df['certification'] == 'NC-17'].copy()
nr_df = tmdb_df.loc[tmdb_df['certification'] == 'NR'].copy()
g_df.head()

# %%
# Define features of interest
g_rev = g_df['revenue']
pg_rev = pg_df['revenue']
pg_13_rev = pg_13_df['revenue']
r_rev = r_df['revenue']
nc_17_rev = nc_17_df['revenue']
nr_rev = nr_df['revenue']
g_rev.head()

# %%
# Find mean of each group
g_mean = g_rev.mean()
print(f'The average mean for G rated movies: ${g_mean:0.2f}')
pg_mean = pg_rev.mean()
print(f'The average mean for PG rated movies: ${pg_mean:0.2f}')
pg_13_mean = pg_13_rev.mean()
print(f'The average mean for PG-13 rated movies: ${pg_13_mean:0.2f}')
r_mean = r_rev.mean()
print(f'The average mean for R rated movies: ${r_mean:0.2f}')
nc_17_mean = nc_17_rev.mean()
print(f'The average mean for NC-17 rated movies: ${nc_17_mean:0.2f}')
nr_mean = nr_rev.mean()
print(f'The average mean for NR rated movies: ${nr_mean:0.2f}')

# %%
# Visualize distribution of each group
rating_palette = {'G':'dodgerblue','PG':'salmon','PG-13':'mediumorchid',
                  'R':'lightgreen','NC-17':'bisque','NR':'lightgrey'}
fig, (ax_bar) = plt.subplots(figsize=(10,6))

# Barplot
sns.barplot(data=tmdb_df, x='certification', y='revenue', ax=ax_bar, palette=rating_palette)
ax_bar.ticklabel_format(style='plain', axis='y')
fig.suptitle('Comparison of Revenue by MPAA Ratings', fontsize='xx-large');

# %%
# Use function to find outliers
find_outliers(tmdb_df['revenue'])

# %%
## save a dictionary of the T/F outlier index for each feature in outleir_cols
outlier_cols = ['revenue']

outliers = {}
for col in outlier_cols:
    outliers_col = find_outliers(tmdb_df[col])
    outliers[col] = outliers_col

# %%
# loop through dictionary to remove outliers
for col, idx_outliers in outliers.items():
    tmdb_df = tmdb_df[~idx_outliers]
tmdb_df

# %%
# Create groups dictionary
# Empty dictionary
groups = {}

# For loop to iterate through dataframe to assign certifications to keys and 
# revenue to values
for i in tmdb_df['certification'].unique():
    
    # Get series for group and rename
    data = tmdb_df.loc[tmdb_df['certification'] == i, 'revenue'].copy()
    
    # Save into dictionary
    groups[i] = data
groups.keys()

# %%
# Test normality
# Run normal test on each group
norm_results = {}

for i, data in groups.items():
    stat, p = stats.normaltest(data)
    norm_results[i] = {'n': len(data), 'p': p, 'test stat': stat}

# Convert to dataframe
norm_results_df = pd.DataFrame(norm_results).T
### checking sig with pandas 
norm_results_df['sig'] = norm_results_df['p'] < .05 
norm_results_df

# %% [markdown]
# > All of the certification groups had significant pvalues (p<0.05) so none of the groups are normal. We can ignore this since we have enough samples in each group.

# %%
# Testing for equal variance
stats.levene(*groups.values())

# %% [markdown]
# > The levene test had a pvalue < 0.05 so we will need to use an alternative test

# %%
# Perform Kruskal-Walllis test
result = stats.kruskal(*groups.values())
result

# %% [markdown]
# > The pvalue is < 0.05 so we reject the null hypothesis. Now we need to run a Pairwise multiple comparisons test to compare the groups

# %%
# Save the values as revenue and the labels to the certifications
values = tmdb_df['revenue']
labels = tmdb_df['certification']

# %%
# Perform tukey's multiple comparison test and display the summary
tukeys_results = pairwise_tukeyhsd(values,labels)
tukeys_results.summary()

# %% [markdown]
# - G-rated movies had a significant difference with NC-17, NR, R-rated movies
# - NC-17-rated movies had a significant difference with PG, PG-13-rated movies
# - NR movies had a significant difference with PG, PG-13-rated movies
# - PG-rated movies had a significant difference with PG-13, R-rated movies
# - PG-13-rated movies had a significant difference with R-rated movies

# %% [markdown]
# ## Does a movies genre affect the revenue the movie generates?

# %% [markdown]
# ### Hypotheses and Choosing Test

# %% [markdown]
# **Hypotheses:**
#
#     1. Null Hypothesis: The genre of a movie does not affect how much revenue a movie generates
#
#     2. Alternative Hypothesis: The genre of a movie does affect the amount of money a movie generates

# %% [markdown]
# **Choosing the Appropriate Test:**
#
# - The data we are looking for in the groups is numerical (revenue)
# - There are more than two groups (Genres)
# - ***Test: One Way ANOVA***

# %% [markdown]
# ### One Way ANOVA Test

# %% [markdown]
# **Test Assumptions:**
#
# - No significant outliers
# - Equal variance
# - Normality

# %%
# Query MySQL database to join genres and revenue
q = '''select g.genres_split, data.revenue
from title_genres g
join tmdb_data as data
on g.tconst = data.imdb_id;'''

genre_rev_df = pd.read_sql(q,engine)
genre_rev_df.head()

# %%
genre_rev_df['genres_split'].value_counts()

# %%
# Visualize distribution of each group
fig, ax_bar = plt.subplots(figsize=(16,10))

# Barplot
sns.barplot(data=genre_rev_df, x='genres_split', y='revenue', ax=ax_bar)
ax_bar.ticklabel_format(style='plain', axis='y')
ax_bar.set_xlabel('Genres',fontsize=12)
ax_bar.set_ylabel('Revenue',fontsize=12)
plt.xticks(rotation=45)
fig.suptitle('Comparison of Revenue by Movie Genres', fontsize='xx-large');

# %%
# Use function to find outliers
find_outliers(genre_rev_df['revenue'])

# %%
## save a dictionary of the T/F outlier index for each feature in outleir_cols
outlier_cols = ['revenue']

outliers = {}
for col in outlier_cols:
    outliers_col = find_outliers(genre_rev_df[col])
    outliers[col] = outliers_col

# %%
# loop through dictionary to remove outliers
for col, idx_outliers in outliers.items():
    genre_rev_df = genre_rev_df[~idx_outliers]
genre_rev_df

# %%
# Create groups dictionary
# Empty dictionary
groups = {}

# For loop to iterate through dataframe to assign certifications to keys and 
# revenue to values
for i in genre_rev_df['genres_split'].unique():
    
    # Get series for group and rename
    data = genre_rev_df.loc[genre_rev_df['genres_split'] == i, 'revenue'].copy()
    
    # Save into dictionary
    groups[i] = data
groups.keys()

# %%
# Test normality
# Run normal test on each group
norm_results = {}

for i, data in groups.items():
    stat, p = stats.normaltest(data)
    norm_results[i] = {'n': len(data), 'p': p, 'test stat': stat}

# Convert to dataframe
norm_results_df = pd.DataFrame(norm_results).T
### checking sig with pandas 
norm_results_df['sig'] = norm_results_df['p'] < .05 
norm_results_df

# %% [markdown]
# > All of the genre groups had significant pvalues (p<0.05) so none of the groups are normal. We can ignore this since we have enough samples in each group

# %%
# Testing for equal variance
stats.levene(*groups.values())

# %% [markdown]
# > The levene test had a pvalue < 0.05 so we will need to use an alternative test

# %%
# Perform Kruskal-Walllis test
result = stats.kruskal(*groups.values())
result

# %% [markdown]
# > The pvalue is < 0.05 so we reject the null hypothesis. Now we need to run a Pairwise multiple comparisons test to compare the groups

# %%
# Save the values as revenue and the labels to the certifications
values = genre_rev_df['revenue']
labels = genre_rev_df['genres_split']

# %%
# Perform tukey's multiple comparison test and display the summary
tukeys_results = pairwise_tukeyhsd(values,labels)
tukeys_results.summary()
