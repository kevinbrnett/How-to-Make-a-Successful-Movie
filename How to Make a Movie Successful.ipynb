# %% [markdown]
# # How to Make a Movie Successful
# - Kevin Barnett
# > Data Dictionary: https://www.imdb.com/interfaces/

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Creating DataFrames

# %%
# URLs for data
title_basics = 'https://datasets.imdbws.com/title.basics.tsv.gz'
title_akas = 'https://datasets.imdbws.com/title.akas.tsv.gz'
title_rating = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
# Pandas dataframes
basics = pd.read_csv(title_basics, sep='\t', low_memory=False)
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9808970 entries, 0 to 9808969
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 673.5+ MB
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# Change column titles to lowercase
basics.columns = basics.columns.str.lower()
basics.head()
# Out:
#       tconst titletype            primarytitle           originaltitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isadult startyear endyear runtimeminutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
akas = pd.read_csv(title_akas, sep='\t', low_memory=False)
akas.info()
akas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35736618 entries, 0 to 35736617
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ GB
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
# Change column titles to lowercase
akas.columns = akas.columns.str.lower()
akas.head()
# Out:
#      titleid  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isoriginaltitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
rating = pd.read_csv(title_rating, sep='\t', low_memory=False)
rating.info()
rating.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1306416 entries, 0 to 1306415
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1306416 non-null  object
#  1   averageRating  1306416 non-null  float64
#  2   numVotes       1306416 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 29.9+ MB
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1966
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1808
# 3  tt0000004            5.6       178
# 4  tt0000005            6.2      2607

# %%
# Change column titles to lowercase
rating.columns = rating.columns.str.lower()
rating.head()
# Out:
#       tconst  averagerating  numvotes
# 0  tt0000001            5.7      1966
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1808
# 3  tt0000004            5.6       178
# 4  tt0000005            6.2      2607

# %% [markdown]
# ## Data Cleaning

# %%
# Basics df
# Replace '\N with np.nan'
basics.replace({'\\N':'np.nan'}, inplace=True)
basics.head()
# Out:
#       tconst titletype            primarytitle           originaltitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isadult startyear endyear runtimeminutes                    genres
# 0       0      1894  np.nan              1         Documentary,Short
# 1       0      1892  np.nan              5           Animation,Short
# 2       0      1892  np.nan              4  Animation,Comedy,Romance
# 3       0      1892  np.nan             12           Animation,Short
# 4       0      1893  np.nan              1              Comedy,Short

# %%
# Eliminate movies that are null for runtimeminutes
(basics['runtimeminutes'] == 'np.nan').sum()
# Out:
# 6918513

# %%
basics.drop(basics[basics['runtimeminutes'] == 'np.nan'].index, inplace = True)
(basics['runtimeminutes'] == 'np.nan').sum()
# Out:
# 0

# %%
# Eliminate movies that are null for genre
(basics['genres'] == 'np.nan').sum()
# Out:
# 76565

# %%
basics.drop(basics[basics['genres'] == 'np.nan'].index, inplace = True)
(basics['genres'] == 'np.nan').sum()
# Out:
# 0

# %%
# Keep only titletype == movie
basics['titletype'].value_counts()
# Out:
# tvEpisode       1426853
# short            599384
# movie            381525
# video            180172
# tvMovie           91437
# tvSeries          90224
# tvSpecial         18057
# tvMiniSeries      17127
# tvShort            8791
# videoGame           322
# Name: titletype, dtype: int64

# %%
basics.drop(basics[basics['titletype'] != 'movie'].index, inplace = True)
basics['titletype'].value_counts()
# Out:
# movie    381525
# Name: titletype, dtype: int64

# %%
# Keep startyear == 2000-2022
basics['startyear'].value_counts()
# Out:
# 2017    14366
# 2018    14322
# 2019    14055
# 2016    13949
# 2015    13475
#         ...
# 1904        1
# 1897        1
# 1896        1
# 2026        1
# 1894        1
# Name: startyear, Length: 131, dtype: int64

# %%
basics.drop(basics[basics['startyear'] <= '2000'].index, inplace = True)
basics.drop(basics[basics['startyear'] >= '2022'].index, inplace = True)
basics['startyear'].value_counts()
# Out:
# 2017    14366
# 2018    14322
# 2019    14055
# 2016    13949
# 2015    13475
# 2014    13100
# 2013    12379
# 2021    12326
# 2012    11625
# 2020    11564
# 2011    10774
# 2010    10201
# 2009     9351
# 2008     8148
# 2007     6962
# 2006     6514
# 2005     5829
# 2004     5201
# 2003     4587
# 2002     4130
# 2001     3861
# Name: startyear, dtype: int64

# %%
# Convert to 'startyear' to float64
basics['startyear'] = basics['startyear'].astype('float64')
basics.dtypes
# Out:
# tconst             object
# titletype          object
# primarytitle       object
# originaltitle      object
# isadult            object
# startyear         float64
# endyear            object
# runtimeminutes     object
# genres             object
# dtype: object

# %%
# Eliminate movies that have 'documentary' in the genre
documentary = basics['genres'].str.contains('documentary', case = False)
basics = basics[~documentary]
(basics['genres'].str.contains('documetary')).sum()
# Out:
# 0

# %%
# Keep only movies in the US
akas['region'].value_counts()
# Out:
# DE    4279086
# FR    4274797
# JP    4273600
# IN    4214461
# ES    4195054
#        ...
# JE          2
# NU          1
# TV          1
# PW          1
# NR          1
# Name: region, Length: 248, dtype: int64

# %%
akas.drop(akas[akas['region'] != 'US'].index, inplace = True)
akas.value_counts()
# Out:
# titleid     ordering  title                             region  language  types        attributes  isoriginaltitle
# tt0000001   6         Carmencita                        US      \N        imdbDisplay  \N          0                  1
# tt26655903  2         Nothing, Forever                  US      \N        \N           \N          0                  1
# tt26656128  1         Robye's BLUE                      US      \N        \N           \N          0                  1
# tt2665610   3         With Snail and I                  US      \N        imdbDisplay  \N          0                  1
#             2         With Snail & I                    US      \N        alternative  \N          0                  1
#                                                                                                                      ..
# tt1166371   3         It Is Written!                    US      \N        alternative  \N          0                  1
#             2         It Is Written with John Bradshaw  US      \N        imdbDisplay  \N          0                  1
# tt1166370   1         Interview with the Devil          US      \N        \N           \N          0                  1
# tt11663694  1         Mad Libs 2                        US      \N        imdbDisplay  \N          0                  1
# tt9916764   1         38                                US      \N        imdbDisplay  \N          0                  1
# Length: 1432914, dtype: int64

# %%
# Filter basics df to only include movies from the US
US_basics = basics['tconst'].isin(akas['titleid'])
US_basics
# Out:
# 34803       True
# 61116       True
# 67669       True
# 77964      False
# 86801       True
#            ...
# 9808643     True
# 9808652     True
# 9808691    False
# 9808736     True
# 9808820    False
# Name: tconst, Length: 135639, dtype: bool

# %%
basics = basics[US_basics]
basics
# Out:
#             tconst titletype  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9808108  tt9914942     movie
# 9808503  tt9915872     movie
# 9808643  tt9916170     movie
# 9808652  tt9916190     movie
# 9808736  tt9916362     movie
#
#                                               primarytitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9808108                             Life Without Sara Amat
# 9808503                               The Last White Witch
# 9808643                                      The Rehearsal
# 9808652                                          Safeguard
# 9808736                                              Coven
#
#                                      originaltitle isadult  startyear endyear  \
# 34803                               Kate & Leopold       0     2001.0  np.nan
# 61116    El tango del viudo y su espejo deformante       0     2020.0  np.nan
# 67669                   The Other Side of the Wind       0     2018.0  np.nan
# 86801                            The Naked Monster       0     2005.0  np.nan
# 93938                         Crime and Punishment       0     2002.0  np.nan
# ...                                            ...     ...        ...     ...
# 9808108                 La vida sense la Sara Amat       0     2019.0  np.nan
# 9808503                  My Girlfriend is a Wizard       0     2019.0  np.nan
# 9808643                                   O Ensaio       0     2019.0  np.nan
# 9808652                                  Safeguard       0     2020.0  np.nan
# 9808736                                   Akelarre       0     2020.0  np.nan
#
#         runtimeminutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9808108             74                      Drama
# 9808503             97       Comedy,Drama,Fantasy
# 9808643             51                      Drama
# 9808652             95  Action,Adventure,Thriller
# 9808736             92              Drama,History
#
# [80190 rows x 9 columns]

# %%
# Replace '\N' with np.nan in akas df
akas.replace({'\\N':'np.nan'}, inplace = True)
akas.head()
# Out:
#       titleid  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US   np.nan  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US   np.nan       np.nan
# 33  tt0000005        10        Blacksmith Scene     US   np.nan  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US   np.nan  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US   np.nan  alternative
#
#                attributes isoriginaltitle
# 5                  np.nan               0
# 14  literal English title               0
# 33                 np.nan               0
# 36                 np.nan               0
# 41                 np.nan               0

# %%
# Replace '\N' with np.nan in rating df if applicable
(rating == '\\N').sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
# Filter ratings to only include US movies
US_rating = rating['tconst'].isin(akas['titleid'])
rating = rating[US_rating]
rating
# Out:
#             tconst  averagerating  numvotes
# 0        tt0000001            5.7      1966
# 1        tt0000002            5.8       263
# 4        tt0000005            6.2      2607
# 5        tt0000006            5.2       181
# 6        tt0000007            5.4       816
# ...            ...            ...       ...
# 1306377  tt9916200            8.1       229
# 1306378  tt9916204            8.1       262
# 1306385  tt9916348            8.1        18
# 1306386  tt9916362            6.4      5307
# 1306391  tt9916428            3.8        14
#
# [496788 rows x 3 columns]

# %% [markdown]
# ## Saving Compressed .csv.gz Files

# %%
import os
os.makedirs('Data-Enrichment-Project/Data/')
os.listdir('Data-Enrichment-Project/Data/')
# Out:
# []

# %%
basics.to_csv('Data-Enrichment-Project/Data/title_basics.csv.gz',compression='gzip',index=False)
akas.to_csv('Data-Enrichment-Project/Data/title_akas.csv.gz',compression='gzip',index=False)
rating.to_csv('Data-Enrichment-Project/Data/title_rating.csv.gz',compression='gzip',index=False)

# %%
basics = pd.read_csv('Data-Enrichment-Project/Data/title_basics.csv.gz', low_memory=False)
basics.head()
# Out:
#       tconst titletype                                       primarytitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originaltitle  isadult  startyear endyear  \
# 0                             Kate & Leopold        0     2001.0  np.nan
# 1  El tango del viudo y su espejo deformante        0     2020.0  np.nan
# 2                 The Other Side of the Wind        0     2018.0  np.nan
# 3                          The Naked Monster        0     2005.0  np.nan
# 4                       Crime and Punishment        0     2002.0  np.nan
#
#    runtimeminutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
akas = pd.read_csv('Data-Enrichment-Project/Data/title_akas.csv.gz', low_memory=False)
akas.head()
# Out:
#      titleid  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US   np.nan  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US   np.nan       np.nan
# 2  tt0000005        10        Blacksmith Scene     US   np.nan  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US   np.nan  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US   np.nan  alternative
#
#               attributes isoriginaltitle
# 0                 np.nan               0
# 1  literal English title               0
# 2                 np.nan               0
# 3                 np.nan               0
# 4                 np.nan               0

# %%
rating = pd.read_csv('Data-Enrichment-Project/Data/title_rating.csv.gz', low_memory=False)
rating.head()
# Out:
#       tconst  averagerating  numvotes
# 0  tt0000001            5.7      1966
# 1  tt0000002            5.8       263
# 2  tt0000005            6.2      2607
# 3  tt0000006            5.2       181
# 4  tt0000007            5.4       816
